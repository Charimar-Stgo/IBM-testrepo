# %% [markdown]
# # My Jupyter Notebook on IBM Studio

# %% [markdown]
# **Charimar Santiago**

# %% [markdown]
# Epidemiologist

# %% [markdown]
# *I am interested in data science because I want to learn how to explore and analyze data to gain meaningful insights and solutions.*

# %% [markdown]
# ### The following code adds three numbers and prints the resulting sum.

# %%
a = 189
b = 450
c = 1000
d = a + b + c
print (d)
# Out:
# 1639

# %% [markdown]
# |Date|Time |Location(s) |
# |----|-----|------------|
# |3/20|9:00 |California  |
# |3/21|10:00|~~unknown~~ |
# |3/22|7:00 |   Cuba     |
#
# * Date
# * Time
# * Location
